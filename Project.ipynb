# %%
import pandas as pd
import numpy as np

# Load large dataset
df = pd.read_excel("myexcel.xlsx")
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
# Replace the "height" column with random numbers
df['Height'] = np.random.randint(150, 181, size=len(df))

# %%
# Save the updated dataset
df.to_csv("updated_myexcel.xlsx", index=False)

df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     167     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     167     235
# 2     John Holland  Boston Celtics      30       SG   27     170     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     176     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     159     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     152     203
# 454      Raul Neto       Utah Jazz      25       PG   24     156     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     172     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     170     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#To Delete a whole column 
# df.drop(columns=['height'], inplace=True)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.**

# %%
Number_of_Players=df.groupby('Team').size()
Number_of_Players
# Out:
# Team
# Atlanta Hawks             15
# Boston Celtics            15
# Brooklyn Nets             15
# Charlotte Hornets         15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Dallas Mavericks          15
# Denver Nuggets            15
# Detroit Pistons           15
# Golden State Warriors     15
# Houston Rockets           15
# Indiana Pacers            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Memphis Grizzlies         18
# Miami Heat                15
# Milwaukee Bucks           16
# Minnesota Timberwolves    14
# New Orleans Pelicans      19
# New York Knicks           16
# Oklahoma City Thunder     15
# Orlando Magic             14
# Philadelphia 76ers        15
# Phoenix Suns              15
# Portland Trail Blazers    15
# Sacramento Kings          15
# San Antonio Spurs         15
# Toronto Raptors           15
# Utah Jazz                 16
# Washington Wizards        15
# dtype: int64

# %%
df['Team'].count()
# Out:
# 458

# %%
Percentage_split=(Number_of_Players/df['Team'].count())*100
Percentage_split
# Out:
# Team
# Atlanta Hawks             3.275109
# Boston Celtics            3.275109
# Brooklyn Nets             3.275109
# Charlotte Hornets         3.275109
# Chicago Bulls             3.275109
# Cleveland Cavaliers       3.275109
# Dallas Mavericks          3.275109
# Denver Nuggets            3.275109
# Detroit Pistons           3.275109
# Golden State Warriors     3.275109
# Houston Rockets           3.275109
# Indiana Pacers            3.275109
# Los Angeles Clippers      3.275109
# Los Angeles Lakers        3.275109
# Memphis Grizzlies         3.930131
# Miami Heat                3.275109
# Milwaukee Bucks           3.493450
# Minnesota Timberwolves    3.056769
# New Orleans Pelicans      4.148472
# New York Knicks           3.493450
# Oklahoma City Thunder     3.275109
# Orlando Magic             3.056769
# Philadelphia 76ers        3.275109
# Phoenix Suns              3.275109
# Portland Trail Blazers    3.275109
# Sacramento Kings          3.275109
# ...

# %%
combained_data_team = pd.DataFrame({
    'Team': team_distribution.index,
    'Number of Players': team_distribution.values,
    'Percentage Split (%)': team_percentage.values
})

# Plot using Seaborn
plt.figure(figsize=(14, 10))
sns.barplot(data=combained_data_team, x='Team', y='Percentage Split (%)', color='skyblue', edgecolor='black')
plt.title('Percentage Split of Employees Across Teams')
plt.ylabel('Percentage (%)')
plt.xlabel('Teams')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **2. Segregate employees based on their positions within the company.**

# %%
#THis gives the value for the whole Nba
df.groupby('Position').size()
# Out:
# Position
# C      79
# PF    100
# PG     92
# SF     85
# SG    102
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of players in each position
position_counts = df.groupby('Position').size()

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=position_counts.index, y=position_counts.values, palette='viridis',hue=position_counts.index,legend=Fal)
plt.title('Number of Players in Each Position')
plt.xlabel('Position')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(position_counts.values, labels=position_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis', len(position_counts)))
plt.title('Distribution of Players Across Positions')
plt.show()

# %%
#This splits even  more detailed in each team in the  whole NBA
x=df.groupby(['Position','Team']).size()
#This is for seeing all rows in the answer
#pd.set_option('display.max_rows', None) 
print(x)
# Out:
# Position  Team
# C         Atlanta Hawks             3
#           Boston Celtics            3
#           Brooklyn Nets             2
#           Charlotte Hornets         3
#           Chicago Bulls             2
#           Cleveland Cavaliers       3
#           Dallas Mavericks          3
#           Denver Nuggets            3
#           Detroit Pistons           3
#           Golden State Warriors     3
#           Houston Rockets           2
#           Indiana Pacers            2
#           Los Angeles Clippers      2
#           Los Angeles Lakers        3
#           Memphis Grizzlies         1
#           Miami Heat                1
#           Milwaukee Bucks           2
#           Minnesota Timberwolves    3
#           New Orleans Pelicans      3
#           New York Knicks           2
#           Oklahoma City Thunder     3
#           Orlando Magic             2
#           Philadelphia 76ers        2
#           Phoenix Suns              3
# ...

# %%
# Count the number of players in each position for each team
position_count = df.groupby(['Team', 'Position']).size().reset_index(name='Number of Players')

# Create a barplot
plt.figure(figsize=(12, 6))
sns.barplot(x='Team', y='Number of Players', hue='Position', data=position_count)
plt.title('Number of Players by Position per Team')
plt.xticks(rotation=90)
plt.ylabel('Number of Players')
plt.show()

# %% [markdown]
# Insights:Shows team Construction on each position, in which teams concentrate on special postions. each team is differently constructed
#
# scoring guard and power forward has more number of players(from(line.Nr:400))
# and players who play center posion has less number of players(line nr 400) when we compare whole association

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **3. Identify the predominant age group among employees.**

# %%
age_gp=df.groupby('Age').size()
age_gp
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    46
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# dtype: int64

# %%
#To find highest number ie which row has maximum
x1=age_gp.max() 
print('number  of players:',x1)
#To find Age at which the highst number exist  
y1=age_gp.idxmax()
print('Age at which highest number  of players:',y1)

print(f"the highest number of players is {x1} at the Age of{y1} .")
# Out:
# number  of players: 47
# Age at which highest number  of players: 24
# the highest number of players is 47 at the Age of24 .

# %%
# Histogram to show age distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], bins=10, kde=True)
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# *Most of the players laying around 25 year plus or minus 2,as the age goes up the number of players decreases(logngitivity reduces)*

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **4. Discover which team and position have the highest salary expenditure.**

# %%
Highest_salaried=df.groupby(['Team', 'Position','Name','Salary'])['Salary'].sum()
Highest_salaried
# Out:
# Team                    Position  Name                      Salary
# Atlanta Hawks           C         Al Horford                12000000.0    12000000.0
#                                   Tiago Splitter            9756250.0      9756250.0
#                                   Walter Tavares            1000000.0      1000000.0
#                         PF        Kris Humphries            1000000.0      1000000.0
#                                   Mike Muscala              947276.0        947276.0
#                                   Mike Scott                3333333.0      3333333.0
#                                   Paul Millsap              18671659.0    18671659.0
#                         PG        Dennis Schroder           1763400.0      1763400.0
#                                   Jeff Teague               8000000.0      8000000.0
#                         SF        Kent Bazemore             2000000.0      2000000.0
# ...

# %%
print("Highest Payed Player ")
Highest_salaried.idxmax()
# Out:
# Highest Payed Player
# ('Los Angeles Lakers', 'SF', 'Kobe Bryant', 25000000.0)

# %%
salary_expenditure = df.groupby(['Team','Position'])['Salary'].sum().reset_index()
salary_expenditure
# Out:
#                        Team Position      Salary
# 0             Atlanta Hawks        C  22756250.0
# 1             Atlanta Hawks       PF  23952268.0
# 2             Atlanta Hawks       PG   9763400.0
# 3             Atlanta Hawks       SF   6000000.0
# 4             Atlanta Hawks       SG  10431032.0
# 5            Boston Celtics        C   7351395.0
# 6            Boston Celtics       PF  18170960.0
# 7            Boston Celtics       PG  19898606.0
# 8            Boston Celtics       SF   6796117.0
# 9            Boston Celtics       SG   6323990.0
# 10            Brooklyn Nets        C  20636276.0
# 11            Brooklyn Nets       PF  14304819.0
# 12            Brooklyn Nets       PG   8747276.0
# 13            Brooklyn Nets       SG   8840104.0
# 14        Charlotte Hornets        C  20316720.0
# 15        Charlotte Hornets       PF  14057310.0
# 16        Charlotte Hornets       PG  14328455.0
# 17        Charlotte Hornets       SF   6331404.0
# ...

# %%
x=salary_expenditure.sort_values(by='Salary',ascending=False)
print(x.head()) #just to see thtop payments)
# Out:
#                    Team Position      Salary
# 67   Los Angeles Lakers       SF  31866445.0
# 75           Miami Heat       PF  31538671.0
# 53      Houston Rockets       SG  28122883.0
# 116        Phoenix Suns       PG  28002998.0
# 37       Denver Nuggets       SF  27982771.0

# %%
salary_expenditure.loc[salary_expenditure['Salary'].idxmax()]
# Out:
# Team        Los Angeles Lakers
# Position                    SF
# Salary              31866445.0
# Name: 67, dtype: object

# %% [markdown]
# **Another Try**

# %%
# Total salary by position
salary_by_position = df.groupby(['Team','Position'])['Salary'].sum().sort_values(ascending=False)

# Total salary by position
print("Salary expenditure by position:\n",salary_by_position)
# Out:
# Salary expenditure by position:
#  Team                    Position
# Los Angeles Lakers      SF          31866445.0
# Miami Heat              PF          31538671.0
# Houston Rockets         SG          28122883.0
# Phoenix Suns            PG          28002998.0
# Denver Nuggets          SF          27982771.0
# Cleveland Cavaliers     PF          27882029.0
# New Orleans Pelicans    SG          27489643.0
# Sacramento Kings        C           26950230.0
# Oklahoma City Thunder   SF          25798862.0
# Los Angeles Clippers    PG          25527217.0
# New York Knicks         SF          25387789.0
# Milwaukee Bucks         SG          25380316.0
# Washington Wizards      C           24490429.0
# Atlanta Hawks           PF          23952268.0
# Cleveland Cavaliers     SF          23917776.0
# Charlotte Hornets       SG          23307031.0
# Houston Rockets         C           23306640.0
# Indiana Pacers          SF          22873211.0
# ...

# %%
# Total salary by team
salary_by_team = df.groupby('Team')['Salary'].sum().sort_values(ascending=False)

print("Salary Expenditure by Team:\n", salary_by_team)
# Out:
# Salary Expenditure by Team:
#  Team
# Cleveland Cavaliers       106988689.0
# Los Angeles Clippers       94854640.0
# Oklahoma City Thunder      93765298.0
# Golden State Warriors      88868997.0
# Chicago Bulls              86783378.0
# San Antonio Spurs          84442733.0
# New Orleans Pelicans       82750774.0
# Miami Heat                 82515673.0
# Charlotte Hornets          78340920.0
# Memphis Grizzlies          76550880.0
# Washington Wizards         76328636.0
# Houston Rockets            75283021.0
# New York Knicks            73303898.0
# Atlanta Hawks              72902950.0
# Los Angeles Lakers         71770431.0
# Sacramento Kings           71683666.0
# Dallas Mavericks           71198732.0
# Toronto Raptors            71117611.0
# Milwaukee Bucks            69603517.0
# Detroit Pistons            67168263.0
# Indiana Pacers             66751826.0
# Utah Jazz                  64007367.0
# Phoenix Suns               63445135.0
# Orlando Magic              60161470.0
# ...

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
salary_by_team.plot(kind='bar', color='lightblue')
plt.title("Salary Expenditure by Team")
plt.ylabel("Total Salary")
plt.xlabel("Teams")
# Out:
# Text(0.5, 0, 'Teams')

# %% [markdown]
# Total salary expenditure Cleveland cavs has more expenditure,and 76ers have less expenditure,majority of the teams expenditure lies betwee .6 to .85 region

# %%
plt.figure(figsize=(20, 5))
#plt.subplot(1, 2, 2)
salary_by_position.plot(kind='bar', color='lightgreen')
plt.title("Salary Expenditure by Position")
plt.ylabel("Total Salary")
plt.xlabel("Positions")

#plt.tight_layout()
plt.show()

# %% [markdown]
# for a position los angels lakers and Miami heat pays more in the forward position(sf.pf).((from the previous insights ie from Q3 it can be understood that it is because of the most payed players in that list[line:nr:553]))

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **5. Investigate if there's any correlation between age and salary, and represent it visually.**

# %%
correlation = df['Age'].corr(df['Salary'])
correlation
#print(f"Correlation between Age and Salary: {correlation:.2f}")
# Out:
# 0.21400941226570971

# %%
print(f"Correlation between Age and Salary: {correlation:.2f}")
# Out:
# Correlation between Age and Salary: 0.21

# %%
import seaborn as sns

# Visualization: Scatter Plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Age', y='Salary', data=df, color='purple', alpha=0.6)
plt.title("Correlation Between Age and Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# Correlation Between Age and Salary:
#
# seems to be a slight positive correlation between age and salary
# shows that older employees seems to earn higher salaries
#
# The age diversity within teams varies, with some teams showing a clear preference for younger, less expensive players, while others may prioritize veteran players with more experience.
# Teams with a larger percentage of players in the 26-30 age group may focus on the peak physical years of players

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **DATA STORY AND INSIGHTS**

# %% [markdown]
# **1. Age vs Salary Trends:**
#
# A positive correlation between age and salary is often observed, where older players tend to earn more due to their experience and accomplishments. However, there are exceptions (young players with exceptional potential or recent performance).

# %% [markdown]
# **2. Team Structure:**
#
# Some teams may focus more on building up a certain position, like point guards or forwards. Teams with balanced positions may reflect a more versatile approach to game strategy.

# %% [markdown]
# **3. Salary Expenditure Insights:**
#
# Teams with higher salary expenditures on specific positions (like centers or point guards) may show the strategic importance of certain roles. For instance, teams investing more in key playmakers like point guards may focus on creating a strong offensive system.

# %% [markdown]
# **4. Age Distribution:**
#
# Many teams may have a young roster with a large concentration of players in their early twenties. This could be indicative of a rebuilding phase, where teams focus on developing young talent over paying high salaries to veterans.

# %% [markdown]
# **5. Age Group Composition:**
#
#     The age diversity within teams varies, with some teams showing a clear preference for younger, less expensive players, while others may prioritize veteran players with more experience. Teams with a larger percentage of players in the 26-30 age group may focus on the peak physical years of players
